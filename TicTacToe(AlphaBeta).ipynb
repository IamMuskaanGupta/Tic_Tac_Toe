# %%
# !pip install pade
import copy
import pickle
import random
from pade.misc.utility import display_message, start_loop
from pade.core.agent import Agent
from pade.acl.aid import AID
from pade.acl.messages import ACLMessage
from enum import Enum
# Out:
# Collecting pade
#   Downloading https://files.pythonhosted.org/packages/b4/af/b8820fc42f9c5ffdcff39f569a2b719f7938083617d01cf8000e161462aa/pade-2.2.4-py3-none-any.whl (187kB)
#      |████████████████████████████████| 194kB 5.5MB/s
# Collecting Flask-WTF==0.14.3
#   Downloading https://files.pythonhosted.org/packages/36/a9/8c01171066bd7a524ee005d81bb4a8aa446ab178043a1ad6cb5dc8f0bd83/Flask_WTF-0.14.3-py2.py3-none-any.whl
# Collecting terminaltables==3.1.0
#   Downloading https://files.pythonhosted.org/packages/9b/c4/4a21174f32f8a7e1104798c445dacdc1d4df86f2f26722767034e4de4bff/terminaltables-3.1.0.tar.gz
# Collecting twisted==20.3.0
#   Downloading https://files.pythonhosted.org/packages/b7/04/1a664c9e5ec0224a1c1a154ddecaa4dc7b8967521bba225efcc41a03d5f3/Twisted-20.3.0-cp36-cp36m-manylinux1_x86_64.whl (3.1MB)
#      |████████████████████████████████| 3.1MB 7.2MB/s
# Requirement already satisfied: requests==2.23.0 in /usr/local/lib/python3.6/dist-packages (from pade) (2.23.0)
# Collecting Flask-SQLAlchemy==2.4.1
#   Downloading https://files.pythonhosted.org/packages/1e/65/226d95466c75e34e291a76890ed0e27af2e46ab913002847856f11d4d59d/Flask_SQLAlchemy-2.4.1-py2.py3-none-any.whl
# Collecting Flask-Login==0.5.0
#   Downloading https://files.pythonhosted.org/packages/2b/83/ac5bf3279f969704fc1e63f050c50e10985e50fd340e6069ec7e09df5442/Flask_Login-0.5.0-py2.py3-none-any.whl
# Collecting Flask-Migrate==2.5.3
#   Downloading https://files.pythonhosted.org/packages/e5/64/c75f173ba5420f5174be6f04dfa8d8250d4808c12a9cd781e84c0b31684f/Flask_Migrate-2.5.3-py2.py3-none-any.whl
# Collecting Flask-Script==2.0.6
#   Downloading https://files.pythonhosted.org/packages/00/a4/cd587b2b19f043b65bf33ceda2f6e4e6cdbd0ce18d01a52b9559781b1da6/Flask-Script-2.0.6.tar.gz (43kB)
#      |████████████████████████████████| 51kB 6.7MB/s
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.6/dist-packages (from pade) (7.1.2)
# Requirement already satisfied: Flask==1.1.2 in /usr/local/lib/python3.6/dist-packages (from pade) (1.1.2)
# Collecting pagan==0.4.3
#   Downloading https://files.pythonhosted.org/packages/29/fd/3ab414cf529ee2e0d926d66f8eb37727c8a4face4fdb0b3f486b8bf6d94a/pagan-0.4.3.tar.gz
# Collecting Flask-Bootstrap==3.3.7.1
#   Downloading https://files.pythonhosted.org/packages/88/53/958ce7c2aa26280b7fd7f3eecbf13053f1302ee2acb1db58ef32e1c23c2a/Flask-Bootstrap-3.3.7.1.tar.gz (456kB)
#      |████████████████████████████████| 460kB 40.6MB/s
# Collecting SQLAlchemy==1.3.15
#   Downloading https://files.pythonhosted.org/packages/8c/30/4134e726dd5ed13728ff814fa91fc01c447ad8700504653fe99d91fdd34b/SQLAlchemy-1.3.15.tar.gz (6.1MB)
#      |████████████████████████████████| 6.1MB 32.7MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting alchimia==0.8.1
#   Downloading https://files.pythonhosted.org/packages/d2/41/7bf9f947d845318d0c8603c98e8dfae39151398793d5bb46ad9757139062/alchimia-0.8.1-py2.py3-none-any.whl
# Requirement already satisfied: itsdangerous in /usr/local/lib/python3.6/dist-packages (from Flask-WTF==0.14.3->pade) (1.1.0)
# Collecting WTForms
#   Downloading https://files.pythonhosted.org/packages/e0/31/614fc7dc7d76005b0acb8c0c8920d962b83d7422b4ba912886dfb63f86ff/WTForms-2.3.3-py2.py3-none-any.whl (169kB)
#      |████████████████████████████████| 174kB 43.9MB/s
# Collecting hyperlink>=17.1.1
#   Downloading https://files.pythonhosted.org/packages/6e/aa/8caf6a0a3e62863cbb9dab27135660acba46903b703e224f14f447e57934/hyperlink-21.0.0-py2.py3-none-any.whl (74kB)
#      |████████████████████████████████| 81kB 8.7MB/s
# Collecting incremental>=16.10.1
#   Downloading https://files.pythonhosted.org/packages/f5/1d/c98a587dc06e107115cf4a58b49de20b19222c83d75335a192052af4c4b7/incremental-17.5.0-py2.py3-none-any.whl
# Collecting zope.interface>=4.4.2
#   Downloading https://files.pythonhosted.org/packages/82/b0/da8afd9b3bd50c7665ecdac062f182982af1173c9081f9af7261091c5588/zope.interface-5.2.0-cp36-cp36m-manylinux2010_x86_64.whl (236kB)
#      |████████████████████████████████| 245kB 42.6MB/s
# Collecting PyHamcrest!=1.10.0,>=1.9.0
#   Downloading https://files.pythonhosted.org/packages/40/16/e54cc65891f01cb62893540f44ffd3e8dab0a22443e1b438f1a9f5574bee/PyHamcrest-2.0.2-py3-none-any.whl (52kB)
#      |████████████████████████████████| 61kB 6.9MB/s
# Collecting constantly>=15.1
#   Downloading https://files.pythonhosted.org/packages/b9/65/48c1909d0c0aeae6c10213340ce682db01b48ea900a7d9fce7a7910ff318/constantly-15.1.0-py2.py3-none-any.whl
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.6/dist-packages (from twisted==20.3.0->pade) (20.3.0)
# Collecting Automat>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/dd/83/5f6f3c1a562674d65efc320257bdc0873ec53147835aeef7762fe7585273/Automat-20.2.0-py2.py3-none-any.whl
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests==2.23.0->pade) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests==2.23.0->pade) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests==2.23.0->pade) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests==2.23.0->pade) (1.24.3)
# Collecting alembic>=0.7
#   Downloading https://files.pythonhosted.org/packages/a9/53/daab5c96e22e9ed1c9f8ca4e3256e72213ade42d519b6254c32e59610967/alembic-1.5.4.tar.gz (1.1MB)
#      |████████████████████████████████| 1.1MB 44.2MB/s
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from Flask==1.1.2->pade) (1.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from Flask==1.1.2->pade) (2.11.3)
# Requirement already satisfied: Pillow>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from pagan==0.4.3->pade) (7.0.0)
# Collecting dominate
#   Downloading https://files.pythonhosted.org/packages/ef/a8/4354f8122c39e35516a2708746d89db5e339c867abbd8e0179bccee4b7f9/dominate-2.6.0-py2.py3-none-any.whl
# Collecting visitor
#   Downloading https://files.pythonhosted.org/packages/d7/58/785fcd6de4210049da5fafe62301b197f044f3835393594be368547142b0/visitor-0.1.3.tar.gz
# Requirement already satisfied: MarkupSafe in /usr/local/lib/python3.6/dist-packages (from WTForms->Flask-WTF==0.14.3->pade) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from zope.interface>=4.4.2->twisted==20.3.0->pade) (53.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from Automat>=0.3.0->twisted==20.3.0->pade) (1.15.0)
# Collecting Mako
#   Downloading https://files.pythonhosted.org/packages/5c/db/2d2d88b924aa4674a080aae83b59ea19d593250bfe5ed789947c21736785/Mako-1.1.4.tar.gz (479kB)
#      |████████████████████████████████| 481kB 36.0MB/s
# Collecting python-editor>=0.3
#   Downloading https://files.pythonhosted.org/packages/c6/d3/201fc3abe391bbae6606e6f1d598c15d367033332bd54352b12f35513717/python_editor-1.0.4-py3-none-any.whl
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from alembic>=0.7->Flask-Migrate==2.5.3->pade) (2.8.1)
# Building wheels for collected packages: SQLAlchemy
#   Building wheel for SQLAlchemy (PEP 517) ... done
#   Created wheel for SQLAlchemy: filename=SQLAlchemy-1.3.15-cp36-cp36m-linux_x86_64.whl size=1228305 sha256=a3be80b2a9f0b74ea0911528d2122a06d3a1b5d8a0e4963dffe2498407e35289
#   Stored in directory: /root/.cache/pip/wheels/24/7f/c8/8d776916c91c613d593f39a98cad373442c7f77027340eb1ec
# Successfully built SQLAlchemy
# Building wheels for collected packages: terminaltables, Flask-Script, pagan, Flask-Bootstrap, alembic, visitor, Mako
#   Building wheel for terminaltables (setup.py) ... done
#   Created wheel for terminaltables: filename=terminaltables-3.1.0-cp36-none-any.whl size=15358 sha256=c90d9e1ebe79806fdee05b8046473f4ab85f385a7c871d2be4bfd4aba39dd618
#   Stored in directory: /root/.cache/pip/wheels/30/6b/50/6c75775b681fb36cdfac7f19799888ef9d8813aff9e379663e
#   Building wheel for Flask-Script (setup.py) ... done
#   Created wheel for Flask-Script: filename=Flask_Script-2.0.6-cp36-none-any.whl size=14016 sha256=5cc9351ead4531e2183803df34f6a7788eb046fd5f0d2dfdd57fa7c084333731
#   Stored in directory: /root/.cache/pip/wheels/1c/17/70/4598e6dba4bec58c1b59552c6409272aea31978ab8159f11a1
#   Building wheel for pagan (setup.py) ... done
#   Created wheel for pagan: filename=pagan-0.4.3-cp36-none-any.whl size=23114 sha256=32c9e4e2a886fffae189429bb675797b24589b041b91ef113ff04a5ef90248c1
#   Stored in directory: /root/.cache/pip/wheels/c2/f1/e8/be2604ef804fee64cd4f700e5947d65b117f6de5a43fae17bd
#   Building wheel for Flask-Bootstrap (setup.py) ... done
#   Created wheel for Flask-Bootstrap: filename=Flask_Bootstrap-3.3.7.1-cp36-none-any.whl size=460123 sha256=461fce6afb076ef1c2f7c23f6beb2bfb2aab1961b9b173810ec97924ba00c4d9
#   Stored in directory: /root/.cache/pip/wheels/e8/b9/93/ef6ac3b8ead2d72cbcc042b9d58b613aaf47e533b9dc5b5999
#   Building wheel for alembic (setup.py) ... done
#   Created wheel for alembic: filename=alembic-1.5.4-py2.py3-none-any.whl size=156314 sha256=080955cc656da5498abf1d49c1e2131f6bf9f03d15e2aaf9be25f036ce2acf91
#   Stored in directory: /root/.cache/pip/wheels/fd/2d/ec/5a1b1e2363ed68392d292d215facf588d5448198edd8078bc1
#   Building wheel for visitor (setup.py) ... done
#   Created wheel for visitor: filename=visitor-0.1.3-cp36-none-any.whl size=3932 sha256=6720cb6e430f1e0df93fb12bf7c3c4d874f9853b349392ebdc4788111c1c93cf
#   Stored in directory: /root/.cache/pip/wheels/68/b0/a2/cc8c7cf94ca3d1088a7d2e27936c1e0da170e05f560973e8dd
#   Building wheel for Mako (setup.py) ... done
#   Created wheel for Mako: filename=Mako-1.1.4-py2.py3-none-any.whl size=75675 sha256=52487005405ced2b8c12bf790334d960cb200a22617067bbdafd709417852bf5
#   Stored in directory: /root/.cache/pip/wheels/ad/10/d3/aeb26e20d19045e2a68e5d3cbb57432e11b5d9c92c99f98d47
# Successfully built terminaltables Flask-Script pagan Flask-Bootstrap alembic visitor Mako
# Installing collected packages: WTForms, Flask-WTF, terminaltables, hyperlink, incremental, zope.interface, PyHamcrest, constantly, Automat, twisted, SQLAlchemy, Flask-SQLAlchemy, Flask-Login, Mako, python-editor, alembic, Flask-Migrate, Flask-Script, pagan, dominate, visitor, Flask-Bootstrap, alchimia, pade
#   Found existing installation: SQLAlchemy 1.3.23
#     Uninstalling SQLAlchemy-1.3.23:
#       Successfully uninstalled SQLAlchemy-1.3.23
# Successfully installed Automat-20.2.0 Flask-Bootstrap-3.3.7.1 Flask-Login-0.5.0 Flask-Migrate-2.5.3 Flask-SQLAlchemy-2.4.1 Flask-Script-2.0.6 Flask-WTF-0.14.3 Mako-1.1.4 PyHamcrest-2.0.2 SQLAlchemy-1.3.15 WTForms-2.3.3 alchimia-0.8.1 alembic-1.5.4 constantly-15.1.0 dominate-2.6.0 hyperlink-21.0.0 incremental-17.5.0 pade-2.2.4 pagan-0.4.3 python-editor-1.0.4 terminaltables-3.1.0 twisted-20.3.0 visitor-0.1.3 zope.interface-5.2.0

# %%
import copy
import pickle
import random
from pade.misc.utility import display_message, start_loop
from pade.core.agent import Agent
from pade.acl.aid import AID
from pade.acl.messages import ACLMessage
from enum import Enum


MAGIC_SQUARE = [[8, 3, 4], [1, 5, 9], [6, 7, 2]]


class Player(Enum):
    HUMAN = 1
    COMPUTER = 2
    NONE = 3


PLAYER_X = "X"
PLAYER_O = "O"


class TicTacToe:
    def __init__(self):
        self.n = 3
        self.board = [
            list(range(start, start + self.n))
            for start in list(range(1, self.n * self.n + 1, self.n))
        ]
        self.current_player = PLAYER_X
        self.player_1_list = []
        self.player_2_list = []
        self.player_1 = Player.NONE
        self.player_2 = Player.NONE
        self.outcome = ""
        self.winner = Player.NONE

    def __is_computer_first_player(self):
        return bool(random.getrandbits(1))

    def random_select_first_player(self):
        if self.__is_computer_first_player():
            self.player_1 = Player.COMPUTER
            self.player_2 = Player.HUMAN
            self.mark_square(5)
            print("Computer goes first it marks square: 5")
        else:
            self.player_1 = Player.HUMAN
            self.player_2 = Player.COMPUTER

    def print_board(self):
        for r in self.board:
            print(end="| ")
            for val in r:
                print(val, end=" | ")
            print()

    def check_square_marked(self, val):
        if val == PLAYER_O or val == PLAYER_X:
            return True
        return not any(val in x for x in self.board)

    def empty_squares_list(self):
        result = []
        for r in range(self.n):
            for c in range(self.n):
                if self.board[r][c] != PLAYER_O and self.board[r][c] != PLAYER_X:
                    result.append(self.board[r][c])
        return result

    def mark_square(self, pos):
        for r in range(self.n):
            for c in range(self.n):
                sqr_value = self.board[r][c]
                if sqr_value == pos:
                    self.board[r][c] = self.current_player
                    if self.current_player == PLAYER_X:
                        self.player_1_list.append(MAGIC_SQUARE[r][c])
                        self.current_player = PLAYER_O
                    elif self.current_player == PLAYER_O:
                        self.player_2_list.append(MAGIC_SQUARE[r][c])
                        self.current_player = PLAYER_X
                    return

    def unmark_square(self, pos):
        self.winner = Player.NONE
        self.outcome = ""
        sqr_number = 1
        if self.current_player == PLAYER_X:
            self.player_2_list.pop()
            self.current_player = PLAYER_O
        else:
            self.player_1_list.pop()
            self.current_player = PLAYER_X
        for r in range(self.n):
            for c in range(self.n):
                if sqr_number == pos:
                    self.board[r][c] = sqr_number
                    return
                sqr_number += 1

    def magic_sqr_to_board(self, sqr_number):
        for i in range(self.n):
            for j in range(self.n):
                if MAGIC_SQUARE[i][j] == sqr_number:
                    return self.board[i][j]

    def _has_won(self, player_list):
        player_list_len = len(player_list)
        for i in range(player_list_len):
            for j in range(i + 1, player_list_len):
                for k in range(j + 1, player_list_len):
                    if player_list[i] + player_list[j] + player_list[k] == 15:
                        return True
        return False

    def check_winner(self):
        if self._has_won(self.player_1_list):
            if self.player_1 == Player.COMPUTER:
                self.outcome = "COMPUTER WON!!"
                self.winner = Player.COMPUTER
            else:
                self.outcome = "HUMAN WON!!"
                self.winner = Player.HUMAN
            return True
        if self._has_won(self.player_2_list):
            if self.player_2 == Player.COMPUTER:
                self.outcome = "COMPUTER WON!!"
                self.winner = Player.COMPUTER
            else:
                self.outcome = "HUMAN WON!!"
                self.winner = Player.HUMAN
            return True
        return False

    def get_winner(self):
        return self.winner

    def check_draw(self):
        for row in self.board:
            for val in row:
                if not (val == "X" or val == "O"):
                    return False
        self.outcome = "DRAW!!"
        return True

    def check_game_over(self):
        return self.check_winner() or self.check_draw() or False

    def reset_board(self):
        self.board = [
            list(range(start, start + self.n))
            for start in list(range(1, self.n * self.n + 1, self.n))
        ]
        self.outcome = ""
        self.player_1_list = []
        self.player_2_list = []
        self.current_player = PLAYER_X

  
class HumanAgent(Agent):
    def __init__(self, aid, computer_agent, tic_tac_toe):
        super().__init__(aid)
        self.computer_agent = computer_agent
        self.tic_tac_toe = tic_tac_toe

    def on_start(self):
        super().on_start()
        display_message(self.aid.localname, "Human Turn")
        self.tic_tac_toe.print_board()
        sqr_number = int(input("Enter square number: "))
        while self.tic_tac_toe.check_square_marked(sqr_number):
            print("Square already marked. Try again!")
            sqr_number = int(input("Enter square number: "))
        self.tic_tac_toe.mark_square(sqr_number)
        self.send_message()

    def react(self, message):
        super().react(message)
        self.tic_tac_toe = pickle.loads(message.content)
        if self.tic_tac_toe.check_game_over():
            print()
            print(self.tic_tac_toe.outcome)
            return
        display_message(self.aid.localname, "human turn")
        sqr_number = int(input("enter square number: "))
        while self.tic_tac_toe.check_square_marked(sqr_number):
            print("square already marked. try again!")
            sqr_number = int(input("enter square number: "))
        self.tic_tac_toe.mark_square(sqr_number)
        self.tic_tac_toe.print_board()
        self.send_message()

    def send_message(self):
        message = ACLMessage(ACLMessage.INFORM)
        message.set_protocol(ACLMessage.FIPA_REQUEST_PROTOCOL)
        message.add_receiver(self.computer_agent)
        self.add_all_agents(message.receivers)
        tic_tac_toe = pickle.dumps(self.tic_tac_toe)
        message.set_content(tic_tac_toe)
        self.send(message)

    def add_all_agents(self, receivers):
        for receiver in receivers:
            self.agentInstance.table[receiver.localname] = receiver


class ComputerAgent(Agent):
    def __init__(self, aid, tic_tac_toe):
        super().__init__(aid)
        self.tic_tac_toe = tic_tac_toe

    def react(self, message):
        super().react(message)
        self.tic_tac_toe = pickle.loads(message.content)
        if self.tic_tac_toe.check_game_over():
            print()
            print(self.tic_tac_toe.outcome)
            return
        display_message(self.aid.localname, "Computer's turn")
        sqr_number = self.make_decision()
        self.tic_tac_toe.mark_square(sqr_number)
        print("Computer marks cell: {}".format(sqr_number))
        self.tic_tac_toe.print_board()
        self.send_message(message.sender.name)

    def send_message(self, receiver_agent):
        message = ACLMessage(ACLMessage.INFORM)
        message.set_protocol(ACLMessage.FIPA_REQUEST_PROTOCOL)
        message.add_receiver(receiver_agent)
        self.add_all_agents(message.receivers)
        tic_tac_toe = pickle.dumps(self.tic_tac_toe)
        message.set_content(tic_tac_toe)
        self.send(message)

    def add_all_agents(self, receivers):
        for receiver in receivers:
            self.agentInstance.table[receiver.localname] = receiver

    def make_decision(self):
        best_sqr = 0
        best_score = float("-inf")
        a=float("-inf")
        b=float("inf")
        empty_squares_list = self.tic_tac_toe.empty_squares_list()
        for sqr_value in empty_squares_list:
            if not self.tic_tac_toe.check_square_marked(sqr_value):
                self.tic_tac_toe.mark_square(sqr_value)
                score = self.minimax(a,b,False)
                self.tic_tac_toe.unmark_square(sqr_value)
                if score > best_score:
                    best_sqr = sqr_value
                    best_score = score
        return best_sqr

    def get_score(self) -> float:
        winner_player = self.tic_tac_toe.get_winner()
        if winner_player == Player.COMPUTER:
            return 10
        if winner_player == Player.HUMAN:
            return -10
        return 0

    def minimax(self, alpha,beta,is_maximizing):
        if self.tic_tac_toe.check_game_over():
            return self.get_score()
        if is_maximizing:
            best_score = float("-inf")
            empty_squares_list = self.tic_tac_toe.empty_squares_list()
            for sqr_value in empty_squares_list:
                if not self.tic_tac_toe.check_square_marked(sqr_value):
                    self.tic_tac_toe.mark_square(sqr_value)
                    score = self.minimax(alpha,beta,not is_maximizing)
                    self.tic_tac_toe.unmark_square(sqr_value)
                    best_score = max(score, best_score)
                    alpha=max(alpha,score)
                    if beta <= alpha:
                      break
            return best_score
        else:
            best_score = float("inf")
            empty_squares_list = self.tic_tac_toe.empty_squares_list()
            for sqr_value in empty_squares_list:
                if not self.tic_tac_toe.check_square_marked(sqr_value):
                    self.tic_tac_toe.mark_square(sqr_value)
                    score = self.minimax(alpha,beta,not is_maximizing)
                    self.tic_tac_toe.unmark_square(sqr_value)
                    best_score = min(score, best_score)
                    beta=min(beta,score)
                    if beta <= alpha:
                      break
            return best_score


if __name__ == "__main__":
    tic_tac_toe = TicTacToe()
    tic_tac_toe.random_select_first_player()
    agents = list()
    human_agent_aid = AID(name="human_agent@localhost:{}".format(30005))
    computer_agent_aid = AID(name="computer_agent@localhost:{}".format(30006))
    computer_agent = ComputerAgent(computer_agent_aid, tic_tac_toe)
    human_agent = HumanAgent(human_agent_aid, computer_agent_aid, tic_tac_toe)
    agents.append(human_agent)
    agents.append(computer_agent)
    start_loop(agents)
# Out:
# [human_agent] 18/02/2021 15:43:42.397 --> Human Turn
# | 1 | 2 | 3 |
# | 4 | 5 | 6 |
# | 7 | 8 | 9 |
# Enter square number: 4
# [computer_agent] 18/02/2021 15:43:48.867 --> Computer's turn
# Computer marks cell: 1
# | O | 2 | 3 |
# | X | 5 | 6 |
# | 7 | 8 | 9 |
# [human_agent] 18/02/2021 15:43:48.979 --> human turn
# enter square number: 5
# | O | 2 | 3 |
# | X | X | 6 |
# | 7 | 8 | 9 |
# [computer_agent] 18/02/2021 15:43:55.795 --> Computer's turn
# Computer marks cell: 6
# | O | 2 | 3 |
# | X | X | O |
# | 7 | 8 | 9 |
# [human_agent] 18/02/2021 15:43:55.810 --> human turn
# enter square number: 2
# | O | X | 3 |
# | X | X | O |
# | 7 | 8 | 9 |
# [computer_agent] 18/02/2021 15:44:03.992 --> Computer's turn
# Computer marks cell: 8
# | O | X | 3 |
# | X | X | O |
# | 7 | O | 9 |
# [human_agent] 18/02/2021 15:44:04.000 --> human turn
# enter square number: 3
# | O | X | X |
# | X | X | O |
# | 7 | O | 9 |
# [computer_agent] 18/02/2021 15:44:17.437 --> Computer's turn
# Computer marks cell: 7
# | O | X | X |
# | X | X | O |
# | O | O | 9 |
# [human_agent] 18/02/2021 15:44:17.445 --> human turn
# enter square number: 9
# | O | X | X |
# | X | X | O |
# | O | O | X |
#
# DRAW!!
